# %% [markdown]
# <a href="https://colab.research.google.com/github/DPatt365/Project_2/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file1 = '/content/healthcare-dataset-stroke-data.csv'
file2 = '/content/rotten_tomatoes_top_movies.csv'

df_stroke = pd.read_csv(file1)
df_movies = pd.read_csv(file2)

# %% [markdown]
# ##Stroke Prediction Data Set

# %% [markdown]
# 1. Source of data
# - Kaggle
# 2. Brief description of data
# -  This data set is used to predict whether a patient is likeley to get a stroked based on gender, age, various diseases, and smoking status.
# 3. What is the target?
# - Stroke (yes or no)
# 4. What does one row represent? (A person?  A business?  An event? A product?)
# - Patient
# 5. Is this a classification or regression problem?
# - Classification
# 6. How many features does the data have?
# - 12
# 7. How many rows are in the dataset?
# - 5,110
# 8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?
# - I don't see forsee any challenges.

# %%
df_stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ##Rotten_Tomatoes_Top_Movies Data Set

# %% [markdown]
# 1. Source of data
# - Kaggle
# 2. Brief description of data
# - This data captures the success of some of Rotten Tomatoes' highest rated films using a combination of technical data and critic scores.
# 3. What is the target?
# - Critic Score
# 4. What does one row represent? (A person?  A business?  An event? A product?)
# - A movie
# 5. Is this a classification or regression problem?
# - Regression
# 6. How many features does the data have?
# - 26
# 7. How many rows are in the dataset?
# - 989
# 8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?
# - I dont forsee any challenges.

# %%
df_movies.head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...
